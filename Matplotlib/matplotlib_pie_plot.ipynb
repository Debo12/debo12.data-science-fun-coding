# %% [markdown]
# <a href="https://colab.research.google.com/github/Debo12/debo12.matplotlib-fp/blob/master/matplotlib_pie_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Pie Plot

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111)
ax.set(title='Avg Qurterly Sales')
sales_2017 = [25782, 35783, 36133]
quarters = ['Q1-2017', 'Q2-2017', 'Q3-2017']
ax.pie(sales_2017, labels=quarters, startangle=90, autopct='%1.2f%%')
plt.show()
