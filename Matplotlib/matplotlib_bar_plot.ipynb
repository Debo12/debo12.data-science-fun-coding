# %% [markdown]
# <a href="https://colab.research.google.com/github/Debo12/debo12.matplotlib-fp/blob/master/matplotlib_bar_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Bar Plot

# %%
fig = plt.figure(num=2, figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)
ax.set(title='Avg Quaterly Sales', xlabel='Quarter', ylabel='Sales')
quarters = [1, 2, 3]
sales_2017 = [25782, 35783, 36133]
ax.bar(quarters, sales_2017, color='orange', edgecolor='red', label='abc')
ax.set_xticks(quarters)
ax.set_xticklabels(['Q1-2017', 'Q2-2017', 'Q3-2017'])
plt.show()

# %% [markdown]
# # Plotting Multiple Groups

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.set(label='Avg Quarterly Sales', xlabel='Quarter', ylabel='Sales (in millions)')
quarters = [1, 2, 3]
x1_index = [0.8, 1.8, 2.8]
x2_index = [1.2, 2.2, 3.2]
sales_2016 = [28831, 30762, 32178]
sales_2017 = [25782, 35783, 36133]
ax.bar(x1_index, sales_2016, color='yellow', width=0.4, edgecolor='black', label='2016')
ax.bar(x2_index, sales_2017, color='orange', width=0.4, edgecolor='black', label='2017')
ax.set_xticks(quarters)
ax.set_xticklabels(['Q1', 'Q2', 'Q3'])
ax.legend()
plt.show()

# %% [markdown]
# # Horizontal Bar Plot

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.set(label='Avg Quarterly Sales', xlabel='Sales (in millions)', ylabel='Quarters')
quarters = [1, 2, 3]
sales_2017 = [25782, 35783, 36133]
ax.barh(quarters, sales_2017, height=0.6, color='red', label='2017')
ax.set_yticks(quarters)
ax.set_yticklabels(['Q1-2017', 'Q2-2017', 'Q3-2017'])
plt.legend()
plt.show()
